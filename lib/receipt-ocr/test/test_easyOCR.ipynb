# %%
import easyocr
import os

# %%
# Load model
reader = easyocr.Reader(['en']) #configure languages

# %%
"""for sample in os.listdir('samples'):
    result = reader.readtext(os.path.join('samples', sample), detail=0)
    print(result)
    print()"""
# Out:
# "for sample in os.listdir('samples'):\n    result = reader.readtext(os.path.join('samples', sample), detail=0)\n    print(result)\n    print()"

# %%
# Test harness: run parse_receipt against stored OCR outputs
import sys, json
sys.path.insert(0, '../../../../../AppData/Local/Temp/Rar$DRa13104.29707.rartemp/receipt ocr')  # allow importing receipt_parser from project root
from receipt_parser import parse_receipt

ocr_outputs = [
    ['Vineria', 'San', 'Te', 'MO', 'PASEO', 'INa', 'DE RIBERA', '41004', 'SEVILLA', 'Tfno:954410600', 'TICKET', '82140', 'Hesa', '24 octubre 2013', 'Hora 21:42', 'jueves,', 'Cant', 'Descr ipcion', 'Precio', 'Total', '2 AGUA MINERAL', '60', '3,20', 'CERVEZA', '50', '3,00', 'TAPA Jamon IBERICO', '30', '4,30', 'COUS COUS DE BROCOLI', '2,90', '2,90', 'QUICHE DE SALMON', '3,20', '3,20', 'TAPA CARPACCIO GAMBONE', '3,90', '3,90', 'TAPa ESPAGUETTIS CON', '3,70', '3,70', 'TAPA BIFE DE TERNERA', '20', '4,20', 'Base', '25,82', 'I.V.A,', '10 %', '2,58 ', 'Tota ', '28,40', 'CATALE'],  # Receipt 1
    ['cexcg', 'Thornton', '#629', '16375 N. Washington St _', 'Thornton, CO 80023', '2X Member', '3i9 Fpszsbgreast', '23.99 E', '673919 FF BS', '49 E', '633561 KS DICED TOM', '967596 JACKORGSALSA', '3 @ 4.29', '12.87 E', '878137  18CT EGGS', '77053 GRAPE TOMATO', '6.29', '404609 ECO HALF PAN', '6.49', '55992 GRND TURKEY', '18. 47 E', '263423 CHPD ONION', '3.59 E', '22101 MonT JACK 2#', '4.45 E', '85.61', 'SUBTOTAL', 'TaX', '3.52', '89 Ka', 'xxx* TOTAL', 'Check /Member Prntd', '89.13', 'CHANGE', '0.00', '8.507 TAX', '0.55', 'E 3.757 TAX', '2.97', 'TOTAL TAX', '3.52', 'TOTAL NUMBER OF ITEMS SOLD', '11', "'95121P11 15;00-629", '172 14', 'OPt; 14 Name: PEPPER', 'Thank', 'You!', 'Please', 'Come', 'Asain', 'Whse : 629 Trm:4 Trn;172 OP:14', '2.97'],  # Receipt 2
    ['Winco', 'Eoods', 'Ji', 'nhe heu', '4 Ru', '9o124 75137', 'er : Yol', 'N/YORK TX GGSC', '18 FS', 'Fs', '7056087677', '56 FS', 'GRND B', '20167400008', 'DIET LN', '20337400o00', 'DRBKSHicks', '20743coo008', '9', 'R', 'EYE RND', '5Tk FP 20146200008', 'EYE RND', '20254300000', '18.28 ES', 'BEEF FOR', '20323300000', '48', 'PORK 1/2 LOIN', '4497921020', 'B/BEST $', '1590013401', 'BAR', 'HAMEAT', "'FRNK 4590001903", '2.88', '0/m', 'WINCO NOODLES', '7055280303', 'TNDRBRO"CHiR4BR 3727101318', '5.98', 'Fs', 'KRFT DELUXE MAC 2100065886', '3.64', '2 0', '82', 'EGGO WAFFLE', '3800037435', 'L/D NUTTY BARS', '2430004120', 'Lid OATMEAL CRM 2430004101', 'LiNKS MILD', '74295503660', 'FGfREVOFRHQUSE', '9222230256', 'H', 'RESERS POT  SLD', '7111719300', 'DM SPAG SAUCE', '2400052363', 'hunTS MANWICH', '2700044212', '82', 'DM PNAPL  CHNKY', '2400000164', '96 FS', '98', "SUNBEAN' BUNS", '7763306333', '1.98', 'WINco SNDwch_WT  7055200115', '91', 'WINCO HoMo MILK 7055240600', '2.48', 'R', 'EGGS', '7003837280', '1.37', 'SUBTOTAL', '121.92', 'TOTAL  TaX', '00', 'IOTAL', '121.92', '47"8700ut4', '06"', 'nincotoade', 'Cockrel|', 'Dunctny  |', 'Et0r@', 'anca', 'Cashl ,', '09/08/14', '11;16.24', '7045400658', '26840100000', 'KINGS', 'CHIGKEN', '7056.096902', 'BLEND', 'PICSWEET', 'GREENS', 'PICSHEET', 'O00OO', '268401C', 'WiNGS', 'CHICKEN', '8', 'CHOP', 'LOIN', '8', 'STEN', 'H', 'STEAK'],  # Receipt 3
    ['X"', 'See back of receipt for', 'chance', 'to', 'win $1000', '62', 'ID #:', '7LORXAKBPJX', '~"', "0*'", '3', 'Walmart', 'Save money: Live better:', '937', ') 644', '2800', 'hanasee-christgssing "9op1', '555 coLexaNs_CROSSTNG', 'Harystntie 0#E;T %3"tRt 98890', 'STI 01695 @PH007573 TEnz10', '3.88', 'Equate LiNeR 068113196503', '7. 48', 'VFis ENG Pom 0051000774', 'F', '97', 'Daun ORIG', '8870090884', '1', 'F8v FGFAPE 8075353878', 'N', 'LINT', 'RoLLERz 005ii7iz3482', 'SubtotAL', '1.25', '0', 'taX', '1', '7.000', '%', 'totaL', '76.60', '1', 'DEBIT', 'TEND', '76.60', 'CHanGE ] DUE', '0.00', "'e", 'EFT  DEBIT', "PayFROH PRIHARY'", '26 . 60', 'TOTAL purchase', '****] {371', '5 EDf.', 'AccounT', 'Xrk* #**X', 'RefvoRk 300030399@PPR CODE 868483', '~Wiat', 'NETVORK ID _', 'TERMINAL', '#SCO10087', '~ODt?', '05/04/17', '19;54:16', "4'", 'Np', 'IteHS SOLD', '6', 'Tct 7635 0523 .2381.1061', '368', '05701/17', '19:64:18', 'Store recelpts', 'on your phone_', 'Valnart', 'P', 'ay -', ',', '{ {.', 'SM . .', 'WJmy."U - \' ]', '~ona bxien ^~~434t', 'Your', '{7'],  # Receipt 4
    [' .@', '#wods', 'Harrods Limited', '87-135 Brompton Road', 'Koigotsbridgex', 'Telephone 020 ,7730  1234', 'www.harrods.COm', 'VAT Number', '629273423', 'Assistant', '16/05/08 14:32', '35046', 'NT0303-000556', '816 9816000726  JELLY BELLY IND', '2.20', "814 90002'", '068272832', '@ 22_', 'Zondek?_Prepack', '1..55', 'Total', 'to Pay', 'dtnathantU$', 'f3.75', 'Cash Tendered', 'E5.00', 'Change', 'f1.25', '0000803030556080516143205', 'HARRODS   REHARDS', 'If you have a Cash Reward_', 'please', 'remember', 'it', 'beforeeft', 'expires', '0n', 'sgesd itybedo8', 'Harrods is now open Sunday 11:30am_', '6pm', '(browsing only between 11:30am', '12noon)'],  # Receipt 5
    ['l6t', '9f recelpt for', 'Your', 'Win s1000', '07edl', 'TJYYZJVOK3Y', 'Walmart', 'Save money. Live', 'ol', '714', '799', '~18285', "6;'4", 'hanager,', '4E', 'BLVQ', 'WESTHS', 'itznsbeA', '7487', '01626', 'Hia6ete8s t', '"op* 0687733', 'Teme', 'Ji', 'subtodAL', '2.8', '~jlmo', 'VISA', '79E05', '2.68', '4- ]', 'VAga', '##rt', '#rr', '#kt', '3670', 's', 'KTHT', 'Reans', '6862051 39884060', 'HakeAF GERvIEEI', 'CeER E', '~too', 'AED', '#EZi', '#No', '~Jot"', '07/22/16', '20:63:11', 'change due', '0,00', 'ITEMS SOLD', '1', 'TCL 76030129', '089 7649', '116', 'You Can Trus=', 'very', "'20;63;1", '#X*cUSTOheR COPYxrt', 'SavIngs Catcher', 'Scan "lth Walnart', 'OPP', '9tedv4 bloV Asban', 'oy', 'ol', " '", 'See', 'back _', 'chance', 'Pn', '  |', '" ,^4', 'Xan ]', 'ft"YG6', '~ut', 'better.', 'w', '"TRI', '7ic', 'Defroveedtt', '"Bo603073"', 'Lou', 'Pr"87/2z746"', 'Day.'],  # Receipt 6
    ['See', 'back', 'recelpt For', 'Your', 'cheince', 'to UIn', "k,8oo'", 'ID', '7KZGFISLZFF', 'Walmart', 'Save money: Live better_', '970', '259', '8755', 'Manager MIKE NEIDLINGER', '1166 $ CaHINO dEL Rio', 'durango Co_81303', '02270 OP# 000144 TE"  0z Tr# 03080', 'sana833t', "'Oooooooo4q11ki", '76 16', 'Ib', '/0. 54', '0.95', 'beveraGE pom', '8031', '{2oo373', '3', '88', '1', 'STRUBRY CC', '076471782200', '96', 'CAHPARI ToH', '073447501213', 'I', '9 F', 'KFT  SINGLES', '002100061626', '1', '44500982114', '004450098211', '98', 'hard SALAHI', '020633960343', '43', 'avocado', '000000004O46KI', 'FOR', 'PILLS', 'AFite', '068113113619', 'Sh NYLON COL', '007417024836', '1', 'HanectrEeuer 884936788883', '8', 'L', 'SubToTAL', '36', 'IaX', '7.900', 'Tax', '8', '6.000', 'i2', 'Tax', '2.900', 'TotaL', '38 , 68', 'Cash', 'TEND', '40. 68', 'chanGe due', '2.00', 'ITeNS SOLd 16', 'TCR3041`7466 0669 7962 277', '01/16/17', '14;26: 03'],  # Receipt 7
    ['See back', 'of receipt for', 'your  chance', 'to win $1000', 'ID #:', '7L2T9HJMZSF', 'Walmart', 'Save money. Live better.', '701', '223', '3066', 'MANAGER TIM MORRIS', '2717 ROCK ISLAND PL', 'BISMARCK ND 58504', 'ST# 01534 OP# 009048 TE# 48 TR# 04455', '6 WING PLATE 020108870398', '3.98', 'ASST 27', '063099656595', '4.88', 'X', 'CUTIE CAR', '063099656644', '12.88', 'SUBTOTAL', '21.74', 'TAX', '6.500', '1.15', 'TAX', '7.500', '0.30', 'TOTAL', '23.19', 'DEBIT', 'TEND', '23.19', 'CHANGE DUE', '0.00', 'EFT DEBIT', 'PAY FROM PRIMARY', '23.19', 'TOTAL   PURCHASE', 'US OEBIT', 'KKii', 'KX*x', 'Trx', '2696', '1 0', 'REF', '# 731700494718', 'NEIWORK Id', '0081 APPR CODE 936886', 'IJS   DEBIT', 'AID A0000000980840', 'TC 58B772390A583B44', '#NO SIGNATURE  REQUIRED', 'TERMINAL', '# SC011090', '11/13/17', '12:34:04', 'ITEMS SOLD', 'TC# 2188 7274 6444 1567 3762', 'Low Prices You Can Trust', 'Every Day', '11/13/17', '12:34:11', 'Store receipts on vour phone', 'Walmart', 'P', 'ay .'],  # Receipt 8
    ['WAL MART', 'Save money. Live better.', 'We SELL FOR LESS', 'MANAGEr', 'DapAVE SESSION', '636', '536', '4601', 'CHESTERFIELD HQ_63005_', "ST#2600 OPi' 00001855 TE ", "'TR# 03359", 'SU FIGURES', '065356920144', '6.63', 'X', 'ToOTHBRUSH', '003500055500', '96', 'SUBTOTAL', 'WOMEN SLIPPE 00972561,4790', '9.86', 'SubTOTAL', 'TAx }', 'X00', '35g01AL', '8', '0', '18', "HcARD' TEND", '18', 'account #3546', 'APPRoval', '7007190', "Trans'ID", 'VALIdATION', 'PayMent   SERVICE', 'CHANGE   DUE', '0.00', 'ITEMS SOLD', '3', 'Tc# 9489 7094 6487 /30733651', 'dol-Hart excluelve Egales CD', 'aval loble October 3oth!', '"10/20/07', '13;48 ; 43', '#**cUSTOHEr copyK**'],  # Receipt 9
    ['I #', 'M1 iswuybkcw', 'Walmart', 'Save money. Live better.', '8443', '21', '0362', 'MANACIR MICHAEL', 'KIGHPD', '2014 $ [6Y', 'M ORENE', 'S 255P"', 'si0 Uz/$ Cph WC 10 TV 49 IRh 0/142', 'Gii| CAI', '08/48860413*3', '50 ,Ou', 'SuDIUI A', '50 . (', 'Tota', '50.60', 'Casi|', '60 . (U', 'CIAMI F', '10 . OC', '"Stkch\'  CAPL ACI IVATION', 'E.0u', 'ACCOLN | 613908546249/20/', 'N"pi:', 'cQl', '192086', 'RLI   H(RESTZ', 'Dal', 'Tvan  Ar ([', 'End Bial', 'UQu', 'Su UJ', '50 . OQ', '08/11[7', '19:', 'Ich Yr*1g 5843 "28/', 'T0 1932', 'FrIces', 'Yuu Cmi Wue', 'Everv [ay .', '(i', '19 22:40', 'Sturer ecins 01', 'Yuu "', 'Fne', 'Walma /', 'ed', '49;31', 'ox'],  # Receipt 10
    ['WHOLE', 'FOODS', 'fnR', 'Ai', 'SHARON', 'RD _', 'TORTILLA" $', 'CAGE', 'FREE', 'ALL', 'UHIT', '3 . 69', 'BLack', 'BEANS', '29', 'Frozen Hangoes', '160', '99', 'Uho ] e', 'Strauberries', '2 . 99', '0g LF', 'cOTTAGE', 'CHEE', '3 . 49', 'HAHi', 'Mahi FILLETS', '8 . 99', 'VC', '$2', 'of f', '(1 ) Uc', 'Fi', '00 -', 'California', 'Harvest', '2.69', '08', 'T6', '99', '[b', 'TARE', '0|', '#WT', 'PLUNS', 'BLack cv', '2. 15', 'ITEM', '4040', 'NHP', 'SLICED OVeN', 'RO', '3 , 99', 'NhP', 'SLICED HICKORY', '3 , 99', '1 , 64', 'Tb', '99', '7b', 'TARE', '01', 'W [', 'GALA', 'APPLES OG', '3,26', 'ITEM', '94135', 'Krkr', 'Tax', '93', 'BAL', '45 . 44'],  # Receipt 11
    ['BQUCHERI ~ \'" , "', '30 RUE ( ` `', 'Balance :', '3', 'Client :', '301', 'D e', '23/01/2022', '11.21', 'icndeur:', '2', 'PASCAL', 'Rayon', '2', '230', 'Num', 'Ticket', '53', 'kg', '€', 'Ikg', '€', 'ONGLET', 'DE BOEUF', '0,380', '29,90', '11,36', 'BIrTECK HACHE SUPER', '0,215', '14,90', '3,20', 'Di vers', '0,', '405', '24,90', '10 ,', '08', 'TOTAL:', '24,64', '3 transaction(s)', '3 Article(+)', 'MERCI', 'DE', 'VOTRE CONFIANCE', 'TEL 0146270446'],  # Receipt 12
    ['SPAR', 'Te]', '036-4481240', 'ela 1', 'bergsparetelkomsa , net', 'VAT  No', '4450102696', 'NLA REG  NO; KZN 032577', 'LAZENBY WORCESTER SAUCE   12SML', '17,99 A', 'MiLKY BAR CHOC', '8OGR', '16,99', 'SMOKED VIENNAS', 'SOOGR', '33,99 A', 'PEALED PEACHES', '40OG', '82,.99 4', 'MEDITERRANEAN MIX', 'IKG', '44,99', 'SPAR COOKING OiL', '375ML', '14,99', 'F/L EnGLiSH CUCUMB', '1"$', '12,99', 'NESTLE AERO', '85GR', '20,,99', 'CADBURY DAIRY MI', 'BOGR', '16,99 4', 'GRAPES  MIXED  TUB', 'TUB', '24,99', 'TASTIC RICE', 'SOOGR', '11,,99', 'BLACK CAT  SMOOTH', '270GR', '27,,99', 'CARRIER BAG 24L', "1'$", '0,75 A', 'BANANAS LOOSE', '17KG', '0,596kg', '15,99 R', '/kg', '9,53', 'TOTAL', 'FOR 14 ITEMS', '338 . 16', 'TENDERED Nedbank', '338 . 16', 'TAX INVOICE', 'VAT rate', 'exc]', 'TaX', 'inc]', '0,00k', '119,48', '0,00', '119,48', '15.00%', '190 ,16', '28,52', '218,68 A', 'SLIP', 'TILL', 'CASHIER', 'DATe', 'TIME', '3780', '005', '101', '23,02,21', '16;17', 'CASHIER NAME: SWAZI', 'Please Retain Slip', 'Thank You For Shopping With Us!', 'Fo] Iow us on Facebook :', 'Spar', 'Bergville'],  # Receipt 13
    ["'eealbeck", 'ou[', 'I #', 'walmar', 'corn', '863-318', '14150)', 'CYPRL S5', 'Mu" ; MaRK', 'M7inieprhavLGanu N3e', 'BLVD', 'Opm', 'FL 27884', '~WAIER', 'I4,36 TRH 05386', 'watik', '007874235191', 'CREAT', '0.98', 'VAI UF', 'GRL Ai Val UE', '0078/4206203', 'GaIN', '007874206293', 'GAinN', 'VEG O11', '003700076954', 'FS', '007874221000', 'CDBR F5 Gpk', '00400005o533', 'MIXED CHOC', '003400029305 E', '004000047587', 'GAIN', '004326880012', 'HY', '01013 /00082355', 'PM 035497333521H', 'GV 202 MINI', '001280051783', 'CRNbRy  KANCE  003620209605', 'SPREADS', '002740026499 F', 'FGGS 6CT', '007874212709', 'SUBTOTAL', 'TAX', '7.000', '.', '', 'TOTAL', ' .', 'DEBTT', 'TEND', 'CHANGE   QUE', '0.00', 'FF DEBTT', 'PaY FRO4 PRIMARY', '86', 'TOTAL PURCHASE', 'FIFTHTHIRD   De bit', 'Fe', 'KKtK', '9832 I 0', 'REF', '# 130400725877', 'NET WORK TD:', '0076 APPR CODE  001740', 'US Debi t', 'AID  A0ocooco042203', 'AAC A8F ABF 300F007485', 'TERMINAL ', 'SC01115i', '10/31/21', '10:08:22', 'ITEMS SULD 18', "ICH  7563' 4623.3938.0953.,7373", 'Low Prices', 'You Can Trust ;', 'Every Dav', '10/31/21', '71o:08:26', 'Givo', 'Iu#', 'Vov', 'voma/isings', 'Walmart -', '~0752', 'S1#', '03447', '(KKU3G', '0078/4215491', 'TTE', '003700077007', 'SNLCKFR', 'CHERRIES', 'RSIIEG', 'BATTERIES'],  # Receipt 14
]

print(f'Parsing {len(ocr_outputs)} receipts\n')
for i, tokens in enumerate(ocr_outputs):
    result = parse_receipt(tokens)
    print(f'Receipt {i+1:02d} | store={result["store"]:20s} total={str(result["total"]):8s} date={result["date"]} | items={len(result["items"])}')
    for item in result['items']:
        print(f'  qty={item["quantity"]}  price={item["price"]:<7}  {item["name"]}')
    print()
# Out:
# Parsing 14 receipts
#
# Receipt 01 | store=Unknown              total=28.4     date=None | items=10
#   qty=2  price=3.2      AGUA MINERAL 60
#   qty=1  price=3.0      CERVEZA 50
#   qty=1  price=4.3      TAPA Jamon IBERICO 30
#   qty=1  price=2.9      COUS COUS DE BROCOLI
#   qty=1  price=3.2      QUICHE DE SALMON
#   qty=1  price=3.9      TAPA CARPACCIO GAMBONE
#   qty=1  price=3.7      TAPa ESPAGUETTIS CON
#   qty=1  price=4.2      TAPA BIFE DE TERNERA 20
#   qty=1  price=25.82    Base
#   qty=1  price=2.58     I.V.A, 10 %
#
# Receipt 02 | store=Costco/Thornton      total=89.13    date=None | items=6
#   qty=3  price=12.87    JACKORGSALSA
#   qty=1  price=6.29     GRAPE TOMATO
#   qty=1  price=6.49     ECO HALF PAN
#   qty=1  price=18.47    GRND TURKEY
#   qty=1  price=3.59     CHPD ONION
#   qty=1  price=4.45     MonT JACK 2#
#
# Receipt 03 | store=WinCo Foods          total=121.92   date=2014-09-08 | items=7
#   qty=1  price=18.28    EYE RND
#   qty=1  price=2.88     'FRNK
# ...

# %%
# Synthetic test harness for new store parsers
# Token lists mimic realistic easyOCR detail=0 output (flat list[str], no coordinates)
import sys, importlib
sys.path.insert(0, '../../../../../AppData/Local/Temp/Rar$DRa13104.29707.rartemp/receipt ocr')
import receipt_parser
importlib.reload(receipt_parser)          # pick up any recent edits without restarting kernel
from receipt_parser import parse_receipt

synthetic_cases = {

    # ── Aldi ─────────────────────────────────────────────────────────────────
    'Aldi': [
        'ALDI', '1801 MISSION ST', 'SAN FRANCISCO CA 94103',
        'BANANA', '0.49',
        'EGGS LG 12CT', '1.89',
        'WHOLE MILK 1GAL', '2.99',
        'SLICED WHITE BREAD', '1.29',
        'SHARP CHEDDAR 8OZ', '2.69',
        'SUBTOTAL', '9.35',
        'TAX', '0.00',
        'TOTAL', '9.35',
        'CASH', '10.00',
        'CHANGE', '0.65',
        '03/15/24', '09:41:17',
    ],

    # ── Trader Joe's ─────────────────────────────────────────────────────────
    "Trader Joe's": [
        "TRADER JOE'S", '302 BROADWAY', 'NEW YORK NY 10013',
        'MANDARIN ORANGE CHICKEN', '4.99',
        'UNEXPECTED CHEDDAR', '3.99',
        'COLD BREW COFFEE RTD', '2.99',
        'DARK CHOC PEANUT BUTTER CUPS', '3.49',
        'SUBTOTAL', '15.46',
        'TAX', '0.00',
        'TOTAL', '15.46',
        'CREDIT', '15.46',
        '03/12/24', '11:25:30',
    ],

    # ── Kroger ───────────────────────────────────────────────────────────────
    # Kroger uses BALANCE instead of TOTAL; has dept headers and "for U" savings
    'Kroger': [
        'Kroger', '456 OAK AVE', 'SPRINGFIELD OH 45501', '(555) 123-4567',
        'PRODUCE',
        'BANANAS', '0.68',
        'for U price', '-0.10',
        'DAIRY',
        'WHOLE MILK 1GAL', '3.49',
        'GROCERY',
        'PENNE PASTA 1LB', '1.29',
        'HONEY BUNCHES OATS', '3.99',
        'Kroger Plus Savings', '-1.00',
        'HOUSEHOLD',
        'PAPER TOWELS 2PK', '5.99',
        'Gas Points Earned: 40',
        'SUBTOTAL', '14.34',
        'TAX', '0.45',
        'BALANCE', '14.79',
        '03/15/24', '10:30:00',
    ],

    # ── Safeway ───────────────────────────────────────────────────────────────
    # Has dept headers, Club Card savings, digital coupons
    'Safeway': [
        'Safeway', '789 ELM BLVD', 'SAN JOSE CA 95101', '(408) 555-9876',
        'PRODUCE',
        'FUJI APPLES 3LB BAG', '3.49',
        'Card Savings', '-1.00',
        'BAKERY',
        'SOURDOUGH ROUND', '4.99',
        'DAIRY',
        'MINUTE MAID OJ 59OZ', '4.99',
        'GROCERY',
        'DICED TOMATOES 14OZ', '1.29',
        'BERTOLLI PASTA SAUCE', '3.49',
        'Digital Coupon', '-0.50',
        'SUBTOTAL', '16.75',
        'TAX', '0.00',
        'TOTAL', '16.75',
        '03/12/24',
    ],

    # ── Meijer ────────────────────────────────────────────────────────────────
    # Has dept headers and mPerks loyalty savings
    'Meijer': [
        'Meijer', '321 GRAND RIVER AVE', 'LANSING MI 48906',
        'PRODUCE',
        'STRAWBERRIES 1LB', '3.99',
        'GROCERY',
        'WONDER BREAD', '2.49',
        'mPerks Savings', '-0.50',
        'CHEERIOS 12OZ', '4.99',
        'mPerks Savings', '-1.50',
        'DAIRY',
        'VANILLA YOGURT 6PK', '3.99',
        'AMERICAN SINGLES 16OZ', '3.99',
        'SUBTOTAL', '17.45',
        'TAX', '1.03',
        'TOTAL', '18.48',
        '03/10/24',
    ],

    # ── Target ────────────────────────────────────────────────────────────────
    # Items prefixed by 9-digit DPCI code; tax line is "T = CA Tax N.NN%"
    'Target': [
        'Target', '555 TARGET PKWY N', 'MINNEAPOLIS MN 55403', '(612) 333-3000',
        '065498213 DOVE BODY WASH 20OZ', '5.99',
        '089321456 COLGATE TOOTHPASTE 6OZ', '3.49',
        '077651298 TIDE PODS 35CT', '12.99',
        '034512678 CHEERIOS 18OZ', '4.99',
        'Target Circle Savings', '-1.00',
        'SUBTOTAL', '26.46',
        'T = CA Tax 8.250%', '2.18',
        'TOTAL', '28.64',
        'RedCard 5% Savings', '-1.43',
        'VISA ENDING 1234', '27.21',
        '03/14/24', '15:42:11',
    ],

    # ── 99 Ranch ──────────────────────────────────────────────────────────────
    # Bilingual: Chinese item labels appear on their own token lines before English
    '99 Ranch': [
        '99 Ranch Market', '1600 SARATOGA AVE', 'SAN JOSE CA 95129',
        '魚丸', 'FISH BALL 14OZ', '2.99',
        '豆腐', 'EXTRA FIRM TOFU', '1.49',
        '白菜', 'NAPA CABBAGE', '1.99',
        '醬油', 'SOY SAUCE 33.8OZ', '3.49',
        'SUBTOTAL', '9.96',
        'TAX', '0.00',
        'TOTAL', '9.96',
        'CASH', '10.00',
        'CHANGE', '0.04',
        '03/11/24',
    ],

    # ── Andronico's ───────────────────────────────────────────────────────────
    # Premium Bay Area grocery; clean format with dept headers
    "Andronico's": [
        "ANDRONICO'S COMMUNITY MARKETS", '1850 SOLANO AVE', 'BERKELEY CA 94707',
        'PRODUCE',
        'ORGANIC BABY SPINACH 5OZ', '4.99',
        'HEIRLOOM TOMATOES LB', '5.99',
        'DAIRY',
        'KERRYGOLD BUTTER 8OZ', '6.99',
        'GROCERY',
        'ACME BREAD LEVAIN', '7.99',
        'DE CECCO PASTA 500G', '4.49',
        'SUBTOTAL', '30.45',
        'TAX', '0.00',
        'TOTAL', '30.45',
        'CREDIT CARD', '30.45',
        '03/13/24',
    ],
}

# ── Run and display ───────────────────────────────────────────────────────────
print(f'{"Store":<20} {"Expected":>9} {"Got Total":>9}  {"Items":>5}  Status')
print('-' * 65)

expected_totals = {
    'Aldi': 9.35,
    "Trader Joe's": 15.46,
    'Kroger': 14.79,
    'Safeway': 16.75,
    'Meijer': 18.48,
    'Target': 28.64,
    '99 Ranch': 9.96,
    "Andronico's": 30.45,
}

all_ok = True
for store_label, tokens in synthetic_cases.items():
    result = parse_receipt(tokens)
    got_store = result['store']
    got_total = result['total']
    exp_total = expected_totals[store_label]
    store_ok = got_store == store_label
    total_ok = got_total is not None and abs(got_total - exp_total) < 0.01
    status = '✓' if (store_ok and total_ok) else '✗'
    if not (store_ok and total_ok):
        all_ok = False
    print(f'{got_store:<20} {exp_total:>9.2f} {str(got_total):>9}  {len(result["items"]):>5}  {status}')
    for item in result['items']:
        print(f'   qty={item["quantity"]}  price={item["price"]:<7.2f}  {item["name"]}')
    print()

print('─' * 65)
print('All checks passed ✓' if all_ok else 'Some checks FAILED — see ✗ rows above')
